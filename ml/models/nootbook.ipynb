# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## 1. Data visualisation

# %%
data= pd.read_csv('dataset/employees_dataset.csv')
pd.set_option('display.max_columns', None)
data.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#check for nulls
pd.set_option('display.max_columns', None)
print(data.isnull().sum())
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.describe(include='all')
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %%
#check for duplicated columns
print(data.duplicated().any())
# Out:
# False

# %%
# data['EmployeeCount'].duplicated().sum()
for x in data.columns:
     if data[x].duplicated().sum() == 1469:
          print(x)
# Out:
# EmployeeCount
# Over18
# StandardHours

# %%
#BusinessTravel, DailyRate, Department, Education, EducationField, EmployeeCount, EnvironmentSatisfaction, Gender, JobInvolvement,JobLevel, JobRole, JobSatisfaction,MaritalStatus, RelationshipSatisfaction ,PerformanceRating,StockOptionLevel, WorkLifeBalance

#DistanceFromHome, EmployeeNumber, HourlyRate, MonthlyIncome, MonthlyRate, NumCompaniesWorked,Over18, OverTime, PercentSalaryHike, StandardHours, TotalWorkingYears, TrainingTimesLastYear,YearsAtCompany, YearsInCurrentRole,YearsSinceLastPromotion, YearsWithCurrManager

# %% [markdown]
# **Visualiser l'impact des variable categorial sur la cible Attrition**

# %%
from numpy import int64
import matplotlib.pyplot as plt

categorial_data=data[['BusinessTravel', 'DailyRate', 'Department', 'Education', 'EducationField', 'EmployeeCount', 'Over18','EnvironmentSatisfaction', 'Gender', 'JobInvolvement','JobLevel', 'JobRole', 'JobSatisfaction','MaritalStatus', 'RelationshipSatisfaction' ,'PerformanceRating','StockOptionLevel', 'WorkLifeBalance']]

data['Attrition']= data['Attrition'].map({'No':0, 'Yes':1})

# %%
nemeric_data= data[['Attrition','DistanceFromHome', 'EmployeeNumber', 'HourlyRate', 'MonthlyIncome', 'MonthlyRate', 'DailyRate','NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear','YearsAtCompany', 'YearsInCurrentRole','YearsSinceLastPromotion', 'YearsWithCurrManager']]
corr_matrix= nemeric_data.corr(numeric_only=True)
plt.figure(figsize=(20,5))
sns.heatmap(corr_matrix,annot=True)
plt.show()
# Out:
#    Attrition  DistanceFromHome  EmployeeNumber  HourlyRate  MonthlyIncome  \
# 0          1                 1               1          94           5993
# 1          0                 8               2          61           5130
# 2          1                 2               4          92           2090
# 3          0                 3               5          56           2909
# 4          0                 2               7          40           3468
#
#    MonthlyRate  DailyRate  NumCompaniesWorked OverTime  PercentSalaryHike  \
# 0        19479       1102                   8      Yes                 11
# 1        24907        279                   1       No                 23
# 2         2396       1373                   6      Yes                 15
# 3        23159       1392                   1      Yes                 11
# 4        16632        591                   9       No                 12
#
#    TotalWorkingYears  TrainingTimesLastYear  YearsAtCompany  \
# ...

# %% [markdown]
# **Boxplot : pour voire si les column numerique contient des outliers**

# %%
#check if there is some outliers
nemeric_data_no_target= nemeric_data.drop(columns=['Attrition'])
plt.figure(figsize=(20,30))
for i, num_feature in enumerate(nemeric_data_no_target.columns):
    plt.subplot(6,3,i+1)
    sns.boxplot(y= num_feature, data= nemeric_data_no_target)
    plt.title(f'boxplot for {num_feature}')

plt.show()

# %% [markdown]
# **Visualiser l'impact des variable categorial sur la cible Attrition**

# %% [markdown]
#  - J’utilise le countplot pour les variables catégorielles parce que la variable cible (Attrition) est également catégorielle.
#  - Le countplot me permet de comparer la distribution des employés ayant quitté l’entreprise et de ceux qui sont restés selon les différentes catégories de chaque variable.
#  - En observant les différences de comptage entre les catégories, je peux identifier quelles variables catégorielles sont le plus fortement associées à l’attrition.

# %%
categorial_data = data[['JobRole', 'BusinessTravel', 'Department', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'JobInvolvement','JobLevel', 'JobSatisfaction','MaritalStatus', 'RelationshipSatisfaction' ,'PerformanceRating','StockOptionLevel', 'WorkLifeBalance']]
for cat in categorial_data:
    plt.figure(figsize= (25,3))
    sns.countplot(x=data[cat], hue=data['Attrition'])
    plt.title(cat)
    plt.show()

# %% [markdown]
# **visualiser si le target est equilibrer**

# %%
sns.countplot(x='Attrition', data=data)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>
